# %%
#Importing pandas
import pandas as pd

# %%
df = pd.read_csv('Sales.csv')

# %%
df.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
df.shape
# Out:
# (113036, 18)

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date                object
# Day                  int64
# Month               object
# Year                 int64
# Customer_Age         int64
# Age_Group           object
# Customer_Gender     object
# Country             object
# State               object
# Product_Category    object
# Sub_Category        object
# Product             object
# Order_Quantity       int64
# Unit_Cost            int64
# Unit_Price           int64
# Profit               int64
# Cost                 int64
# Revenue              int64
# dtype: object

# %%
df.groupby('Country').count()
# Out:
#                  Date    Day  Month   Year  Customer_Age  Age_Group  \
# Country
# Australia       23936  23936  23936  23936         23936      23936
# Canada          14178  14178  14178  14178         14178      14178
# France          10998  10998  10998  10998         10998      10998
# Germany         11098  11098  11098  11098         11098      11098
# United Kingdom  13620  13620  13620  13620         13620      13620
# United States   39206  39206  39206  39206         39206      39206
#
#                 Customer_Gender  State  Product_Category  Sub_Category  \
# Country
# Australia                 23936  23936             23936         23936
# Canada                    14178  14178             14178         14178
# France                    10998  10998             10998         10998
# Germany                   11098  11098             11098         11098
# United Kingdom            13620  13620             13620         13620
# ...

# %%
df.groupby(['Country'])

# %%
df['Revenue'].sum()
# Out:
# 85271008

# %%
df.groupby(['Country','State'])['Revenue'].sum()
# Out:
# Country         State
# Australia       New South Wales         9203495
#                 Queensland              5066267
#                 South Australia         1397274
#                 Tasmania                 580184
#                 Victoria                5054839
# Canada          Alberta                   56803
#                 British Columbia        7877890
#                 Ontario                    1045
# France          Charente-Maritime        106047
#                 Essonne                  973532
#                 Garonne (Haute)          183906
#                 Hauts de Seine           937140
#                 Loir et Cher              82533
#                 Loiret                   325172
#                 Moselle                  266223
#                 Nord                    1324652
#                 Pas de Calais             50413
#                 Seine (Paris)           1643279
#                 Seine Saint Denis       1131634
# ...

# %%
df.groupby(['Country','State'])['Revenue'].sum().apply(lambda x: x * 100 / df['Revenue'].sum()).round(decimals = 0)
# Out:
# Country         State
# Australia       New South Wales        11.0
#                 Queensland              6.0
#                 South Australia         2.0
#                 Tasmania                1.0
#                 Victoria                6.0
# Canada          Alberta                 0.0
#                 British Columbia        9.0
#                 Ontario                 0.0
# France          Charente-Maritime       0.0
#                 Essonne                 1.0
#                 Garonne (Haute)         0.0
#                 Hauts de Seine          1.0
#                 Loir et Cher            0.0
#                 Loiret                  0.0
#                 Moselle                 0.0
#                 Nord                    2.0
#                 Pas de Calais           0.0
#                 Seine (Paris)           2.0
#                 Seine Saint Denis       1.0
#                 Seine et Marne          0.0
#                 Somme                   0.0
# ...

# %%
df.groupby(['Country','State'])['Revenue'].sum().apply(lambda x: x * 100 / df['Revenue'].sum()).round(5)
# Out:
# Country         State
# Australia       New South Wales        10.79323
#                 Queensland              5.94137
#                 South Australia         1.63863
#                 Tasmania                0.68040
#                 Victoria                5.92797
# Canada          Alberta                 0.06661
#                 British Columbia        9.23865
#                 Ontario                 0.00123
# France          Charente-Maritime       0.12436
#                 Essonne                 1.14169
#                 Garonne (Haute)         0.21567
#                 Hauts de Seine          1.09901
#                 Loir et Cher            0.09679
#                 Loiret                  0.38134
#                 Moselle                 0.31221
#                 Nord                    1.55346
#                 Pas de Calais           0.05912
#                 Seine (Paris)           1.92713
#                 Seine Saint Denis       1.32710
# ...

# %%
df.groupby(['Country','State'])['Revenue'].sum().apply(lambda x: x * 100 / df['Revenue'].sum()).round().sort_values(ascending = False)
# Out:
# Country         State
# United States   California             21.0
# United Kingdom  England                12.0
# Australia       New South Wales        11.0
# Canada          British Columbia        9.0
# United States   Washington              8.0
# Australia       Victoria                6.0
#                 Queensland              6.0
# United States   Oregon                  4.0
# France          Nord                    2.0
# Germany         Saarland                2.0
#                 Nordrhein-Westfalen     2.0
#                 Hessen                  2.0
#                 Bayern                  2.0
# France          Seine (Paris)           2.0
# Germany         Hamburg                 2.0
# Australia       South Australia         2.0
# France          Essonne                 1.0
#                 Seine Saint Denis       1.0
#                 Yveline                 1.0
# Australia       Tasmania                1.0
# France          Hauts de Seine          1.0
# ...

# %%
df.groupby(['Country','State'])['Revenue'].sum()
# Out:
# Country         State
# Australia       New South Wales         9203495
#                 Queensland              5066267
#                 South Australia         1397274
#                 Tasmania                 580184
#                 Victoria                5054839
# Canada          Alberta                   56803
#                 British Columbia        7877890
#                 Ontario                    1045
# France          Charente-Maritime        106047
#                 Essonne                  973532
#                 Garonne (Haute)          183906
#                 Hauts de Seine           937140
#                 Loir et Cher              82533
#                 Loiret                   325172
#                 Moselle                  266223
#                 Nord                    1324652
#                 Pas de Calais             50413
#                 Seine (Paris)           1643279
#                 Seine Saint Denis       1131634
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
df.groupby(['Country','Year']).sum()
# Out:
#                         Day  Customer_Age  Order_Quantity  Unit_Cost  \
# Country        Year
# Australia      2011   13610         27586            1707     920710
#                2012   13610         27586            1718     920710
#                2013   84373        178689           58623    2205982
#                2014   90157        205232           72671    1230412
#                2015   84373        178689           57947    2205982
#                2016   90157        205232           70919    1230412
# Canada         2011    3557          7467             429     257781
#                2012    3557          7467             452     257781
#                2013   48736        109034           43326     375920
#                2014   57596        140397           53548     313578
#                2015   48736        109034           42302     375920
#                2016   57596        140397           52202     313578
# ...

# %%
df.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
Pivot2 = pd.crosstab(index = df['Country'], columns = df['Year'], values = df['Revenue'], aggfunc = sum, rownames = ['Country'], margins = True, margins_name = 'Grand Total')
Pivot2
# Out:
# Year               2011     2012      2013      2014      2015      2016  \
# Country
# Australia       2529914  2557511   4107470   2802842   5712339   3591983
# Canada           789798   835527   1443537   1471522   1731954   1663400
# France           946624   962153   1431870   1411100   1877928   1803197
# Germany          833603   835188   1452704   1702508   1931091   2223502
# United Kingdom   823481   834885   1868796   2014044   2484181   2620809
# United States   3041468  3150719   4935660   4750708   6286498   5810494
# Grand Total     8964888  9175983  15240037  14152724  20023991  17713385
#
# Year            Grand Total
# Country
# Australia          21302059
# Canada              7935738
# France              8432872
# Germany             8978596
# United Kingdom     10646196
# United States      27975547
# Grand Total        85271008

# %%
Pivot3 = pd.pivot_table(df, index=['Country', 'State'], columns='Year', values = 'Revenue', aggfunc = sum, margins = True, margins_name = 'Grand Total')
Pivot3
# Out:
# Year                                     2011       2012        2013  \
# Country        State
# Australia      New South Wales      1175012.0  1171056.0   1697649.0
#                Queensland            622846.0   642944.0    975721.0
#                South Australia       138199.0   141107.0    307194.0
#                Tasmania               72073.0    61490.0    134687.0
#                Victoria              521784.0   540914.0    992219.0
# Canada         Alberta                16553.0    11638.0      7348.0
#                British Columbia      773245.0   823889.0   1435633.0
#                Ontario                    NaN        NaN       556.0
# France         Charente-Maritime       9431.0     9286.0     24848.0
#                Essonne               110012.0   116489.0    167261.0
#                Garonne (Haute)        22639.0    18047.0     23372.0
#                Hauts de Seine         98740.0    97361.0    169771.0
# ...
